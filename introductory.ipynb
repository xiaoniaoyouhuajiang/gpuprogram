# %% [markdown]
# # what,why
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 为什么是julia
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# 详情去看
# Numba, Julia的GPU编程(也许会再写点XLA) - 罗秀哲的文章 - 知乎
# https://zhuanlan.zhihu.com/p/40691506

# %% [markdown]
# https://notamonadtutorial.com/julia-gpu-98a461d33e21
